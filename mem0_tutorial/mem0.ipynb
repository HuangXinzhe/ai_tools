# %% [markdown]
# # mem0
# Mem0 为大语言模型提供了一个智能、自我改进的记忆层，实现了跨应用的个性化 AI 体验。其核心功能包括多层次记忆、自适应个性化、开发者友好的 API、跨平台一致性，并且你可以在本地计算机上运行这个程序。
#
# Mem0 是 RAG 发展的下一个阶段，相比 RAG 的核心区别：关注实体和实体关系；关注最近、最相关的；上下文连续性；适应性学习；动态更新信息。而普通 RAG 只是单纯的从静态的文档中检索信息。
#
# 具体来说，Mem0 提供的记忆实现相比 RAG 具有以下优势：
#
# 关注实体关系：Mem0 能理解和关联不同交互中的实体，而 RAG 则从静态文档中检索信息。这使得 Mem0 对上下文和关系的理解更深刻。
#
# 最近性、相关性和衰减：Mem0 优先考虑最近的交互，并逐渐忘记过时的信息，确保记忆保持相关和最新，以提供更准确的响应。
#
# 上下文连续性：Mem0 在多个会话中保留信息，保持对话和交互的连续性，这对于长期参与应用，如虚拟伴侣或个性化学习助手来说至关重要。
#
# 自适应学习：Mem0 根据用户交互和反馈改进其个性化，使记忆随着时间的推移更加准确和贴合个人用户。
#
# 动态更新信息：Mem0 能够根据新的信息和交互动态更新其记忆，而 RAG 依赖于静态数据。这允许实时调整和改进，提升用户体验。
#
# 这些先进的记忆功能使 Mem0 成为开发者创建个性化和上下文感知 AI 应用的强大工具。

# %%
# !pip install mem0ai
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting mem0ai
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/21/2c/e401b41140c0ac2c26c49acd0c3c6a4211f75a38467ed1d43ef0eab1741a/mem0ai-0.0.7-py3-none-any.whl (28 kB)
# Collecting qdrant-client<2.0.0,>=1.9.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e1/64/c13f54fb3786bba876d0c68477a302ccbfa3b73d9c893d0a024441037e0a/qdrant_client-1.10.1-py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Collecting together<2.0.0,>=1.2.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/15/da/d5529e3a8f0d7e934948d99ee9a1abe90bdd36da2b9af013cd62d8528cb9/together-1.2.2-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 7.5 MB/s eta 0:00:00
# Collecting pydantic<3.0.0,>=2.7.3
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1f/fa/b7f815b8c9ad021c07f88875b601222ef5e70619391ade4a49234d12d278/pydantic-2.8.2-py3-none-any.whl (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 7.7 MB/s eta 0:00:00a 0:00:01
# Collecting boto3<2.0.0,>=1.34.144
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/4e/c7/b0b4d4d0e150770f8f0afadc6e4f5f31da0cebed590ff184f3dff2ed25ee/boto3-1.34.145-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 10.5 MB/s eta 0:00:00
# Collecting openai<2.0.0,>=1.33.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ef/f2/ad4ded2fa2c932bc7239fc6bf556423462d3068c4b18396ff943787ef424/openai-1.36.0-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.7/328.7 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: posthog<4.0.0,>=3.5.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from mem0ai) (3.5.0)
# Collecting litellm<2.0.0,>=1.41.24
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/68/e3/7b59bfbe32e3723e85babf999c1e87125083510a04a11fcd9a1fb4b85f8c/litellm-1.41.25-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 10.4 MB/s eta 0:00:00a 0:00:01
# Collecting groq<0.10.0,>=0.9.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/59/7c/81b1302925c2452d540c7d7784b316017b69e1f3f19c2996bcb09360437b/groq-0.9.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 8.9 MB/s eta 0:00:00
# Collecting botocore<1.35.0,>=1.34.145
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/35/48/86b595223cd3159aa3e211a3552ece7bfbcf0d75689465f3c95754f43d26/botocore-1.34.145-py3-none-any.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 9.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from boto3<2.0.0,>=1.34.144->mem0ai) (0.10.0)
# Collecting s3transfer<0.11.0,>=0.10.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3c/4a/b221409913760d26cf4498b7b1741d510c82d3ad38381984a3ddc135ec66/s3transfer-0.10.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from groq<0.10.0,>=0.9.0->mem0ai) (3.5.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from groq<0.10.0,>=0.9.0->mem0ai) (4.12.2)
# Collecting distro<2,>=1.7.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from groq<0.10.0,>=0.9.0->mem0ai) (0.25.1)
# Requirement already satisfied: sniffio in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from groq<0.10.0,>=0.9.0->mem0ai) (1.2.0)
# Requirement already satisfied: tokenizers in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from litellm<2.0.0,>=1.41.24->mem0ai) (0.19.1)
# Collecting jsonschema<5.0.0,>=4.22.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/69/4a/4f9dbeb84e8850557c02365a0eee0649abe5eb1d84af92a25731c6c0f922/jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 6.2 MB/s eta 0:00:00
# Collecting tiktoken>=0.7.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/65/90/84a85b7122853188c343bcf2321f9cec7424ed5cfaedac36a0ada03e9351/tiktoken-0.7.0-cp39-cp39-macosx_11_0_arm64.whl (907 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 907.9/907.9 kB 9.1 MB/s eta 0:00:00a 0:00:01
# Collecting importlib-metadata>=6.8.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/dc/ef/38766b2edb096260d9b1b6ad35adaa0bce3b0567abb452b21eb074af88c4/importlib_metadata-8.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: aiohttp in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from litellm<2.0.0,>=1.41.24->mem0ai) (3.8.5)
# Requirement already satisfied: python-dotenv>=0.2.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from litellm<2.0.0,>=1.41.24->mem0ai) (1.0.1)
# Collecting jinja2<4.0.0,>=3.1.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/31/80/3a54838c3fb461f6fec263ebf3a3a41771bd05190238de3486aae8540c36/jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 7.7 MB/s eta 0:00:00
# Collecting requests<3.0.0,>=2.31.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: click in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from litellm<2.0.0,>=1.41.24->mem0ai) (8.0.4)
# Requirement already satisfied: tqdm>4 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.33.0->mem0ai) (4.65.0)
# Requirement already satisfied: python-dateutil>2.1 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from posthog<4.0.0,>=3.5.0->mem0ai) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from posthog<4.0.0,>=3.5.0->mem0ai) (1.16.0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from posthog<4.0.0,>=3.5.0->mem0ai) (2.2.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from posthog<4.0.0,>=3.5.0->mem0ai) (1.6)
# Collecting pydantic-core==2.20.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/77/f7/25f1fba7ea1ae052e20b234e4c66d54b129e5b3f4d1e6c0da6534dbf57c3/pydantic_core-2.20.1-cp39-cp39-macosx_11_0_arm64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.4 MB/s eta 0:00:0000:0100:01
# Collecting annotated-types>=0.4.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting portalocker<3.0.0,>=2.7.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9b/fb/a70a4214956182e0d7a9099ab17d50bfcba1056188e9b14f35b9e2b62a0d/portalocker-2.10.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai) (1.26.15)
# Collecting grpcio>=1.41.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/db/05/c065360571435cd7769345e4fa0401cedfb56bace460afca074a216cdad1/grpcio-1.65.1-cp39-cp39-macosx_10_9_universal2.whl (10.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 9.3 MB/s eta 0:00:0000:0100:01
# Collecting grpcio-tools>=1.41.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ab/74/093802feb8604bd028fe8fc05811969187bdcc125d10124791bf076e79af/grpcio_tools-1.65.1-cp39-cp39-macosx_10_9_universal2.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 8.5 MB/s eta 0:00:00a 0:00:01m
# Requirement already satisfied: numpy>=1.21 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai) (1.23.5)
# Collecting tqdm>4
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/18/eb/fdb7eb9e48b7b02554e1664afd3bd3f117f6b6d6c5881438a0b055554f9b/tqdm-4.66.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.3 MB/s eta 0:00:00
# Collecting click
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 4.5 MB/s eta 0:00:00
# Collecting tabulate<0.10.0,>=0.9.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting filelock<4.0.0,>=3.13.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ae/f0/48285f0262fe47103a4a45972ed2f9b93e4c80b8fd609fa98da78b2a5706/filelock-3.15.4-py3-none-any.whl (16 kB)
# Requirement already satisfied: typer<0.13,>=0.9 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from together<2.0.0,>=1.2.1->mem0ai) (0.9.4)
# Collecting aiohttp
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/4c/8f/04381aa090cffc3dbb6673935bdb4a7c7690d3bc40949d1e66fc136dac15/aiohttp-3.9.5-cp39-cp39-macosx_11_0_arm64.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.7/390.7 kB 11.2 MB/s eta 0:00:00
# Collecting eval-type-backport<0.3.0,>=0.1.3
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ac/ac/aa3d8e0acbcd71140420bc752d7c9779cf3a2a3bb1d7ef30944e38b2cd39/eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Collecting pillow<11.0.0,>=10.3.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/23/9c/343827267eb28d41cd82b4180d33b10d868af9077abcec0af9793aa77d2d/pillow-10.4.0-cp39-cp39-macosx_11_0_arm64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 10.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pyarrow>=10.0.1 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from together<2.0.0,>=1.2.1->mem0ai) (14.0.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->litellm<2.0.0,>=1.41.24->mem0ai) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->litellm<2.0.0,>=1.41.24->mem0ai) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->litellm<2.0.0,>=1.41.24->mem0ai) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->litellm<2.0.0,>=1.41.24->mem0ai) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->litellm<2.0.0,>=1.41.24->mem0ai) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->litellm<2.0.0,>=1.41.24->mem0ai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->groq<0.10.0,>=0.9.0->mem0ai) (3.4)
# Collecting protobuf<6.0dev,>=5.26.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/75/44/6ae304790fad936bb4cf09907a05d669b7600458a02b6c960fdaaeeab06e/protobuf-5.27.2-cp38-abi3-macosx_10_9_universal2.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.2/412.2 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from grpcio-tools>=1.41.0->qdrant-client<2.0.0,>=1.9.1->mem0ai) (66.0.0)
# Requirement already satisfied: certifi in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->groq<0.10.0,>=0.9.0->mem0ai) (2024.7.4)
# Requirement already satisfied: httpcore in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->groq<0.10.0,>=0.9.0->mem0ai) (1.0.1)
# Collecting h2<5,>=3
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2a/e5/db6d438da759efbb488c4f3fbdab7764492ff3c3f953132efa6b9f0e9e53/h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.41.24->mem0ai) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.41.24->mem0ai) (2.0.1)
# Collecting attrs>=17.3.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e0/44/827b2a91a5816512fcaf3cc4ebc465ccd5d598c45cefa6703fcf4a79018f/attrs-23.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.2 MB/s eta 0:00:00
# Collecting rpds-py>=0.7.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a8/2a/f58fae3d01969fd724c5afb96bb8efe44e001eb385e2890a30949a245345/rpds_py-0.19.0-cp39-cp39-macosx_11_0_arm64.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 kB 10.4 MB/s eta 0:00:00
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ee/07/44bd408781594c4d0a027666ef27fab1e441b109dc3b76b4f836f8fd04fe/jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b7/59/2056f61236782a2c86b33906c025d4f4a0b17be0161b63b70fd9e8775d36/referencing-0.35.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.31.0->litellm<2.0.0,>=1.41.24->mem0ai) (2.0.4)
# Requirement already satisfied: regex>=2022.1.18 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from tiktoken>=0.7.0->litellm<2.0.0,>=1.41.24->mem0ai) (2022.7.9)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from tokenizers->litellm<2.0.0,>=1.41.24->mem0ai) (0.23.4)
# Collecting hpack<5,>=4.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d5/34/e8b383f35b77c402d28563d2b8f83159319b509bc5f760b15d60b0abf165/hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting hyperframe<7,>=6.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d7/de/85a784bcc4a3779d1753a7ec2dee5de90e18c7bcf402e71b51fcf150b129/hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.41.24->mem0ai) (2024.3.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.41.24->mem0ai) (6.0)
# Requirement already satisfied: packaging>=20.9 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.41.24->mem0ai) (23.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/huangxinzhe/opt/anaconda3/lib/python3.9/site-packages (from httpcore->httpx<1,>=0.23.0->groq<0.10.0,>=0.9.0->mem0ai) (0.14.0)
# Installing collected packages: tqdm, tabulate, rpds-py, requests, pydantic-core, protobuf, portalocker, pillow, jinja2, importlib-metadata, hyperframe, hpack, grpcio, filelock, eval-type-backport, distro, click, attrs, annotated-types, tiktoken, referencing, pydantic, h2, grpcio-tools, botocore, aiohttp, together, s3transfer, openai, jsonschema-specifications, groq, qdrant-client, jsonschema, boto3, litellm, mem0ai
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.8.10
#     Uninstalling tabulate-0.8.10:
#       Successfully uninstalled tabulate-0.8.10
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.0
#     Uninstalling protobuf-4.25.0:
#       Successfully uninstalled protobuf-4.25.0
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.9.0
#     Uninstalling filelock-3.9.0:
#       Successfully uninstalled filelock-3.9.0
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.3.3
#     Uninstalling tiktoken-0.3.3:
#       Successfully uninstalled tiktoken-0.3.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.5
#     Uninstalling aiohttp-3.8.5:
#       Successfully uninstalled aiohttp-3.8.5
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.6
#     Uninstalling openai-0.27.6:
#       Successfully uninstalled openai-0.27.6
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.17.3
#     Uninstalling jsonschema-4.17.3:
#       Successfully uninstalled jsonschema-4.17.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# streamlit 1.28.1 requires importlib-metadata<7,>=1.4, but you have importlib-metadata 8.0.0 which is incompatible.
# streamlit 1.28.1 requires protobuf<5,>=3.20, but you have protobuf 5.27.2 which is incompatible.
# llama-index 0.6.1 requires requests<2.30.0, but you have requests 2.32.3 which is incompatible.
# langchain 0.0.155 requires pydantic<2,>=1, but you have pydantic 2.8.2 which is incompatible.
# fastapi 0.95.1 requires pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2, but you have pydantic 2.8.2 which is incompatible.
# datasets 2.16.1 requires fsspec[http]<=2023.10.0,>=2023.1.0, but you have fsspec 2024.3.1 which is incompatible.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.32.3 which is incompatible.
# Successfully installed aiohttp-3.9.5 annotated-types-0.7.0 attrs-23.2.0 boto3-1.34.145 botocore-1.34.145 click-8.1.7 distro-1.9.0 eval-type-backport-0.2.0 filelock-3.15.4 groq-0.9.0 grpcio-1.65.1 grpcio-tools-1.65.1 h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1 importlib-metadata-8.0.0 jinja2-3.1.4 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 litellm-1.41.25 mem0ai-0.0.7 openai-1.36.0 pillow-10.4.0 portalocker-2.10.1 protobuf-5.27.2 pydantic-2.8.2 pydantic-core-2.20.1 qdrant-client-1.10.1 referencing-0.35.1 requests-2.32.3 rpds-py-0.19.0 s3transfer-0.10.2 tabulate-0.9.0 tiktoken-0.7.0 together-1.2.2 tqdm-4.66.4

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["OPENAI_API_BASE"] = os.getenv("OPENAI_API_BASE")

# %%
from mem0 import MemoryClient

client = MemoryClient(api_key=os.environ.get("MEM0_API_KEY"))

# %%
# create long-term memory for users
client.add("Remember my name is Deshraj Yadav.", user_id="deshraj")
client.add("I like to eat pizza and go out on weekends.", user_id="deshraj")
client.add("Oh I am actually allergic to cheese to cannot eat pizza anymore.", user_id="deshraj")
# Out:
# {'message': 'Memory added successfully!'}

# %% [markdown]
# 短时记忆

# %%
client.add("Deshraj is building Gmail AI agent",
           user_id="deshraj", session_id="session-1")
# Out:
# {'message': 'Memory added successfully!'}

# %% [markdown]
# 长时记忆

# %%
client.add("Return short responses when responding to emails",
           agent_id="gmail-agent")
# Out:
# {'message': 'Memory added successfully!'}

# %%
client.get_all(user_id="deshraj")
# Out:
# [{'id': 'dbce6e06-6adf-40b8-9187-3d30bd13b741',
#   'agent': None,
#   'consumer': {'id': 8,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-17T16:47:23.899900-07:00',
#    'updated_at': '2024-07-17T16:47:23.899918-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '57288ac8a87c4ac8d3ac7f2075d264ca',
#   'input': 'Remember my name is Deshraj Yadav.',
#   'text': 'My name is Deshraj Yadav.',
#   'metadata': None,
#   'created_at': '2024-07-17T16:47:25.670180-07:00',
#   'updated_at': '2024-07-17T16:47:25.670197-07:00'},
#  {'id': 'f6dec5d1-b5db-45f5-a2fb-3979a0f27d30',
#   'agent': None,
#   'consumer': {'id': 8,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-17T16:47:23.899900-07:00',
#    'updated_at': '2024-07-17T16:47:23.899918-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '19248f0766044b5973fc0ef1bf3955ef',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I am allergic to cheese so I cannot eat pizza anymore.',
#   'metadata': None,
#   'created_at': '2024-07-17T16:49:38.622084-07:00',
#   'updated_at': '2024-07-17T16:49:38.622101-07:00'},
#  {'id': '5fb8f85d-3383-4bad-9d46-f171272478a4',
#   'agent': None,
#   'consumer': {'id': 8,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-17T16:47:23.899900-07:00',
#    'updated_at': '2024-07-17T16:47:23.899918-07:00'},
#   'app': None,
#   'run': {'id': 1,
#    'run_id': 'session-1',
#    'name': '',
#    'metadata': None,
#    'created_at': '2024-07-01T17:59:08.187250-07:00',
#    'updated_at': '2024-07-01T17:59:08.187266-07:00'},
#   'hash': '179ced9649ac2b85350ece4946b1ee9b',
#   'input': 'Deshraj is building Gmail AI agent',
#   'text': 'Deshraj is building Gmail AI agent',
#   'metadata': None,
#   'created_at': '2024-07-17T16:52:41.278920-07:00',
#   'updated_at': '2024-07-17T16:52:41.278938-07:00'},
#  {'id': '05ca6a0f-b825-4ded-93b2-ea764468bd65',
#   'agent': None,
#   'consumer': {'id': 16,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:03:03.869138-07:00',
#    'updated_at': '2024-07-19T00:03:03.869151-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '6787ac75f4a9cee68685d8232b9dfbe6',
#   'input': 'I like to eat pizza and go out on weekends.',
#   'text': 'Remember my name is Deshraj Yadav.',
#   'metadata': None,
#   'created_at': '2024-07-19T00:03:05.887258-07:00',
#   'updated_at': '2024-07-19T00:03:18.093851-07:00'},
#  {'id': '351fe769-1ae3-4694-8968-a66feac824a2',
#   'agent': None,
#   'consumer': {'id': 16,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:03:03.869138-07:00',
#    'updated_at': '2024-07-19T00:03:03.869151-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '6739ea1c596b391be204f9c5daec280d',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I like to go out on weekends. I am actually allergic to cheese so cannot eat pizza anymore.',
#   'metadata': None,
#   'created_at': '2024-07-19T00:03:17.914275-07:00',
#   'updated_at': '2024-07-19T00:03:31.220283-07:00'},
#  {'id': 'bba2b910-8e46-4ddf-84b1-2552e845cf3b',
#   'agent': None,
#   'consumer': {'id': 16,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:03:03.869138-07:00',
#    'updated_at': '2024-07-19T00:03:03.869151-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '71da019fcef86dc87c25f6708342ddc8',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I am actually allergic to cheese so cannot eat pizza anymore.',
#   'metadata': None,
#   'created_at': '2024-07-19T00:03:31.430824-07:00',
#   'updated_at': '2024-07-19T00:03:31.430843-07:00'},
#  {'id': '04a640ae-6696-4bdd-bc56-00d3504ed5d3',
#   'agent': None,
#   'consumer': {'id': 19,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:59:51.338997-07:00',
#    'updated_at': '2024-07-19T00:59:51.339008-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '6787ac75f4a9cee68685d8232b9dfbe6',
#   'input': 'Remember my name is Deshraj Yadav.',
#   'text': 'Remember my name is Deshraj Yadav.',
#   'metadata': None,
#   'created_at': '2024-07-19T00:59:53.681033-07:00',
#   'updated_at': '2024-07-19T00:59:53.681053-07:00'},
#  {'id': 'cdc7ce7c-cf1e-4370-ad89-8ba7ccbf98e0',
#   'agent': None,
#   'consumer': {'id': 19,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:59:51.338997-07:00',
#    'updated_at': '2024-07-19T00:59:51.339008-07:00'},
#   'app': None,
#   'run': None,
#   'hash': 'f2c6cd4e44e57f81bea19beb40afb601',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I like to go out on weekends. However, I am allergic to cheese and cannot eat pizza anymore.',
#   'metadata': None,
#   'created_at': '2024-07-19T00:59:56.230585-07:00',
#   'updated_at': '2024-07-19T00:59:59.903153-07:00'},
#  {'id': '9a51894b-275c-4032-b704-8b4d27341126',
#   'agent': None,
#   'consumer': {'id': 19,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:59:51.338997-07:00',
#    'updated_at': '2024-07-19T00:59:51.339008-07:00'},
#   'app': None,
#   'run': None,
#   'hash': 'b0c2dfc0bb8afe578ece9e7d0e300e75',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I am allergic to cheese.',
#   'metadata': None,
#   'created_at': '2024-07-19T01:00:00.150829-07:00',
#   'updated_at': '2024-07-19T01:00:00.150863-07:00'},
#  {'id': '2d5af938-95f0-4294-ada4-74657d6c9d61',
#   'agent': None,
#   'consumer': {'id': 27,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T21:04:37.664014-07:00',
#    'updated_at': '2024-07-19T21:04:37.664026-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '57288ac8a87c4ac8d3ac7f2075d264ca',
#   'input': 'Remember my name is Deshraj Yadav.',
#   'text': 'My name is Deshraj Yadav.',
#   'metadata': None,
#   'created_at': '2024-07-19T21:04:39.452732-07:00',
#   'updated_at': '2024-07-19T21:04:39.452750-07:00'},
#  {'id': '16a5f7bf-e5a0-4b14-aace-b4b44f276176',
#   'agent': None,
#   'consumer': {'id': 27,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T21:04:37.664014-07:00',
#    'updated_at': '2024-07-19T21:04:37.664026-07:00'},
#   'app': None,
#   'run': None,
#   'hash': 'c18267413fb1bad71a7f40078975a18c',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I am allergic to cheese, so I cannot eat pizza anymore. I like to go out on weekends.',
#   'metadata': None,
#   'created_at': '2024-07-19T21:04:44.103407-07:00',
#   'updated_at': '2024-07-19T21:04:44.103426-07:00'},
#  {'id': '8e8ba36a-ab46-429b-88c6-65e0ddc2d2f8',
#   'agent': None,
#   'consumer': {'id': 27,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T21:04:37.664014-07:00',
#    'updated_at': '2024-07-19T21:04:37.664026-07:00'},
#   'app': None,
#   'run': {'id': 60,
#    'run_id': 'session-1',
#    'name': '',
#    'metadata': None,
#    'created_at': '2024-07-19T21:06:33.334885-07:00',
#    'updated_at': '2024-07-19T21:06:33.334900-07:00'},
#   'hash': '179ced9649ac2b85350ece4946b1ee9b',
#   'input': 'Deshraj is building Gmail AI agent',
#   'text': 'Deshraj is building Gmail AI agent',
#   'metadata': None,
#   'created_at': '2024-07-19T21:06:34.928525-07:00',
#   'updated_at': '2024-07-19T21:06:34.928542-07:00'}]

# %%
agent_memories = client.get_all(agent_id="gmail-agent")

# %%
agent_memories
# Out:
# [{'id': 'b80dae83-e857-44ea-ae04-3d217897a8c5',
#   'agent': {'id': 5,
#    'agent_id': 'gmail-agent',
#    'name': '',
#    'metadata': None,
#    'created_at': '2024-07-17T16:52:47.217972-07:00',
#    'updated_at': '2024-07-17T16:52:47.217989-07:00'},
#   'consumer': None,
#   'app': None,
#   'run': None,
#   'hash': 'edeae4d9490c319d628f1ef2052559f3',
#   'input': 'Return short responses when responding to emails',
#   'text': 'Return short responses when responding to emails',
#   'metadata': None,
#   'created_at': '2024-07-17T16:52:50.414529-07:00',
#   'updated_at': '2024-07-17T16:52:50.414548-07:00'},
#  {'id': 'f8076d4c-af41-4f6f-b07a-c41be2a6d713',
#   'agent': {'id': 7,
#    'agent_id': 'gmail-agent',
#    'name': '',
#    'metadata': None,
#    'created_at': '2024-07-19T21:06:46.654145-07:00',
#    'updated_at': '2024-07-19T21:06:46.654163-07:00'},
#   'consumer': None,
#   'app': None,
#   'run': None,
#   'hash': 'edeae4d9490c319d628f1ef2052559f3',
#   'input': 'Return short responses when responding to emails',
#   'text': 'Return short responses when responding to emails',
#   'metadata': None,
#   'created_at': '2024-07-19T21:06:48.444385-07:00',
#   'updated_at': '2024-07-19T21:06:48.444404-07:00'}]

# %%
memory = client.get(memory_id="dbce6e06-6adf-40b8-9187-3d30bd13b741")

# %%
memory
# Out:
# {'error': 'Memory not found!'}

# %%
memory_id = "dbce6e06-6adf-40b8-9187-3d30bd13b741"
client.update(memory_id, data="Updated name is Deshraj Kumar")
# Out:
# {'error': 'Memory not found!'}

# %%
history = client.history(memory_id)

# %%
client.search("What does Deshraj like to eat?", user_id="deshraj", limit=3)
# Out:
# [{'id': '04a640ae-6696-4bdd-bc56-00d3504ed5d3',
#   'agent': None,
#   'consumer': {'id': 19,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:59:51.338997-07:00',
#    'updated_at': '2024-07-19T00:59:51.339008-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '6787ac75f4a9cee68685d8232b9dfbe6',
#   'input': 'Remember my name is Deshraj Yadav.',
#   'text': 'Remember my name is Deshraj Yadav.',
#   'metadata': None,
#   'created_at': '2024-07-19T00:59:53.681033-07:00',
#   'updated_at': '2024-07-19T00:59:53.681053-07:00'},
#  {'id': '05ca6a0f-b825-4ded-93b2-ea764468bd65',
#   'agent': None,
#   'consumer': {'id': 16,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:03:03.869138-07:00',
#    'updated_at': '2024-07-19T00:03:03.869151-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '6787ac75f4a9cee68685d8232b9dfbe6',
#   'input': 'I like to eat pizza and go out on weekends.',
#   'text': 'Remember my name is Deshraj Yadav.',
#   'metadata': None,
#   'created_at': '2024-07-19T00:03:05.887258-07:00',
#   'updated_at': '2024-07-19T00:03:18.093851-07:00'},
#  {'id': 'dbce6e06-6adf-40b8-9187-3d30bd13b741',
#   'agent': None,
#   'consumer': {'id': 8,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-17T16:47:23.899900-07:00',
#    'updated_at': '2024-07-17T16:47:23.899918-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '57288ac8a87c4ac8d3ac7f2075d264ca',
#   'input': 'Remember my name is Deshraj Yadav.',
#   'text': 'My name is Deshraj Yadav.',
#   'metadata': None,
#   'created_at': '2024-07-17T16:47:25.670180-07:00',
#   'updated_at': '2024-07-17T16:47:25.670197-07:00'},
#  {'id': '2d5af938-95f0-4294-ada4-74657d6c9d61',
#   'agent': None,
#   'consumer': {'id': 27,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T21:04:37.664014-07:00',
#    'updated_at': '2024-07-19T21:04:37.664026-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '57288ac8a87c4ac8d3ac7f2075d264ca',
#   'input': 'Remember my name is Deshraj Yadav.',
#   'text': 'My name is Deshraj Yadav.',
#   'metadata': None,
#   'created_at': '2024-07-19T21:04:39.452732-07:00',
#   'updated_at': '2024-07-19T21:04:39.452750-07:00'},
#  {'id': '8e8ba36a-ab46-429b-88c6-65e0ddc2d2f8',
#   'agent': None,
#   'consumer': {'id': 27,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T21:04:37.664014-07:00',
#    'updated_at': '2024-07-19T21:04:37.664026-07:00'},
#   'app': None,
#   'run': {'id': 60,
#    'run_id': 'session-1',
#    'name': '',
#    'metadata': None,
#    'created_at': '2024-07-19T21:06:33.334885-07:00',
#    'updated_at': '2024-07-19T21:06:33.334900-07:00'},
#   'hash': '179ced9649ac2b85350ece4946b1ee9b',
#   'input': 'Deshraj is building Gmail AI agent',
#   'text': 'Deshraj is building Gmail AI agent',
#   'metadata': None,
#   'created_at': '2024-07-19T21:06:34.928525-07:00',
#   'updated_at': '2024-07-19T21:06:34.928542-07:00'},
#  {'id': '5fb8f85d-3383-4bad-9d46-f171272478a4',
#   'agent': None,
#   'consumer': {'id': 8,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-17T16:47:23.899900-07:00',
#    'updated_at': '2024-07-17T16:47:23.899918-07:00'},
#   'app': None,
#   'run': {'id': 1,
#    'run_id': 'session-1',
#    'name': '',
#    'metadata': None,
#    'created_at': '2024-07-01T17:59:08.187250-07:00',
#    'updated_at': '2024-07-01T17:59:08.187266-07:00'},
#   'hash': '179ced9649ac2b85350ece4946b1ee9b',
#   'input': 'Deshraj is building Gmail AI agent',
#   'text': 'Deshraj is building Gmail AI agent',
#   'metadata': None,
#   'created_at': '2024-07-17T16:52:41.278920-07:00',
#   'updated_at': '2024-07-17T16:52:41.278938-07:00'},
#  {'id': 'cdc7ce7c-cf1e-4370-ad89-8ba7ccbf98e0',
#   'agent': None,
#   'consumer': {'id': 19,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:59:51.338997-07:00',
#    'updated_at': '2024-07-19T00:59:51.339008-07:00'},
#   'app': None,
#   'run': None,
#   'hash': 'f2c6cd4e44e57f81bea19beb40afb601',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I like to go out on weekends. However, I am allergic to cheese and cannot eat pizza anymore.',
#   'metadata': None,
#   'created_at': '2024-07-19T00:59:56.230585-07:00',
#   'updated_at': '2024-07-19T00:59:59.903153-07:00'},
#  {'id': '351fe769-1ae3-4694-8968-a66feac824a2',
#   'agent': None,
#   'consumer': {'id': 16,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:03:03.869138-07:00',
#    'updated_at': '2024-07-19T00:03:03.869151-07:00'},
#   'app': None,
#   'run': None,
#   'hash': '6739ea1c596b391be204f9c5daec280d',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I like to go out on weekends. I am actually allergic to cheese so cannot eat pizza anymore.',
#   'metadata': None,
#   'created_at': '2024-07-19T00:03:17.914275-07:00',
#   'updated_at': '2024-07-19T00:03:31.220283-07:00'},
#  {'id': '16a5f7bf-e5a0-4b14-aace-b4b44f276176',
#   'agent': None,
#   'consumer': {'id': 27,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T21:04:37.664014-07:00',
#    'updated_at': '2024-07-19T21:04:37.664026-07:00'},
#   'app': None,
#   'run': None,
#   'hash': 'c18267413fb1bad71a7f40078975a18c',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I am allergic to cheese, so I cannot eat pizza anymore. I like to go out on weekends.',
#   'metadata': None,
#   'created_at': '2024-07-19T21:04:44.103407-07:00',
#   'updated_at': '2024-07-19T21:04:44.103426-07:00'},
#  {'id': '9a51894b-275c-4032-b704-8b4d27341126',
#   'agent': None,
#   'consumer': {'id': 19,
#    'user_id': 'deshraj',
#    'metadata': None,
#    'created_at': '2024-07-19T00:59:51.338997-07:00',
#    'updated_at': '2024-07-19T00:59:51.339008-07:00'},
#   'app': None,
#   'run': None,
#   'hash': 'b0c2dfc0bb8afe578ece9e7d0e300e75',
#   'input': 'Oh I am actually allergic to cheese to cannot eat pizza anymore.',
#   'text': 'I am allergic to cheese.',
#   'metadata': None,
#   'created_at': '2024-07-19T01:00:00.150829-07:00',
#   'updated_at': '2024-07-19T01:00:00.150863-07:00'}]

# %%
client.delete(memory_id)
# Out:
# {'error': 'Memory not found!'}

# %%
client.delete_all(user_id="alex")
# Out:
# {'message': 'Memories deleted successfully!'}
