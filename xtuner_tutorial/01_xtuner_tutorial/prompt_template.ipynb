# %% [markdown]
# # 对话模板

# %% [markdown]
# ## 何处需要对话模版？
# - xtuner train:
#     - 需要使用对话模版将训练数据“模版化”，在训练 config 中配置 prompt_template 参数来选择对话模版
#
# - xtuner chat:
#     - 需要使用对话模版将对话文本“模版化”，通过 xtuner chat 命令的 --prompt-template 参数选择对话模版

# %% [markdown]
# ## 对话模板速览
# xtuner.utils.PROMPT_TEMPLATE
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
